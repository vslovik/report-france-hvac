# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')

from cohorts.cohort_performance import WeeklyCohorts

df_clean = pd.read_csv('pipeline_data/cleaned_quote_data.csv')
df_clean['dt_creation_devis'] = pd.to_datetime(df_clean['dt_creation_devis'])
print(f"Loaded data: {len(df_clean):,} quotes from {df_clean['numero_compte'].nunique():,} customers")

# %%
wc = WeeklyCohorts(df_clean)
wc.plot_weekly_cohorts_performance_trend__single_quoters()
wc.plot_weekly_cohorts_performance_trend__switchers()
wc.plot_quarters_report()
wc.plot_intra_quarters()
wc.plot_quarter_x_product_report()
