# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import chi2_contingency
from datetime import timedelta

from cohorts.cohort_performance import plot_weekly_cohorts_performance_trend__single_quoters, get_journey
from cohorts.cohort_performance import plot_weekly_cohorts_performance_trend__switchers
from cohorts.cohort_performance import plot_quarters_report, plot_intra_quarters, plot_quarter_x_product_report
from cohorts.cohort_performance import plot_monthly_cohort_conversion_curves, plot_monthly_cohort_conversion_curves_by_product
from cohorts.cohort_performance import plot_monthly_cohort_conversion_curves_by_agency, plot_monthly_cohort_conversion_curves_by_agency_process


import warnings
warnings.filterwarnings('ignore')

df_clean = pd.read_csv('pipeline_data/cleaned_quote_data.csv')
df_clean['dt_creation_devis'] = pd.to_datetime(df_clean['dt_creation_devis'])
print(f"Loaded data: {len(df_clean):,} quotes from {df_clean['numero_compte'].nunique():,} customers")

print(df_clean.shape)
# print(df_clean.dtypes)
# print(df_clean.head(3).to_string())
# Out:
# Loaded data: 37,008 quotes from 25,716 customers
# (37008, 50)

# %%
# plot_weekly_cohorts_performance_trend__single_quoters(df_clean)
# plot_weekly_cohorts_performance_trend__switchers(df_clean)
# plot_quarters_report(df_clean)
# plot_intra_quarters(df_clean)
# plot_quarter_x_product_report(df_clean)

# %%
plot_monthly_cohort_conversion_curves_by_product(df_clean)
plot_monthly_cohort_conversion_curves(df_clean)
# Out:
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# Full dataset:     25,716 customers
# Excluding 3 LBCs: 23,698 customers
# Removed:          2,018 customers
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# HEAT_PUMP → OTHER               275
# OTHER → HEAT_PUMP               224
# BOILER_GAS → HEAT_PUMP          215
# HEAT_PUMP → STOVE               182
# BOILER_GAS → OTHER              142
# AIR_CONDITIONER → HEAT_PUMP     136
# AIR_CONDITIONER → OTHER         124
# HEAT_PUMP → BOILER_GAS          120
# BOILER_GAS → AIR_CONDITIONER    115
# OTHER → STOVE                   105
# OTHER → AIR_CONDITIONER          94
# OTHER → BOILER_GAS               88
# AIR_CONDITIONER → STOVE          88
# HEAT_PUMP → AIR_CONDITIONER      83
# STOVE → HEAT_PUMP                81
# STOVE → OTHER                    73
# Name: count, dtype: int64
#
# Total switcher segments to plot: 16
# Cohorts: 27  (2024-01 → 2026-03)
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# Full dataset:     25,716 customers
# Excluding 3 LBCs: 23,698 customers
# Removed:          2,018 customers
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# HEAT_PUMP → OTHER               275
# OTHER → HEAT_PUMP               224
# BOILER_GAS → HEAT_PUMP          215
# HEAT_PUMP → STOVE               182
# BOILER_GAS → OTHER              142
# AIR_CONDITIONER → HEAT_PUMP     136
# AIR_CONDITIONER → OTHER         124
# HEAT_PUMP → BOILER_GAS          120
# BOILER_GAS → AIR_CONDITIONER    115
# OTHER → STOVE                   105
# OTHER → AIR_CONDITIONER          94
# OTHER → BOILER_GAS               88
# AIR_CONDITIONER → STOVE          88
# HEAT_PUMP → AIR_CONDITIONER      83
# STOVE → HEAT_PUMP                81
# STOVE → OTHER                    73
# Name: count, dtype: int64
#
# Total switcher segments to plot: 16
# Cohorts: 27  (2024-01 → 2026-03)

# %%
plot_monthly_cohort_conversion_curves_by_agency(df_clean)
plot_monthly_cohort_conversion_curves_by_agency_process(df_clean)
# Out:
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# Full dataset:     25,716 customers
# Excluding 3 LBCs: 23,698 customers
# Removed:          2,018 customers
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# HEAT_PUMP → OTHER               275
# OTHER → HEAT_PUMP               224
# BOILER_GAS → HEAT_PUMP          215
# HEAT_PUMP → STOVE               182
# BOILER_GAS → OTHER              142
# AIR_CONDITIONER → HEAT_PUMP     136
# AIR_CONDITIONER → OTHER         124
# HEAT_PUMP → BOILER_GAS          120
# BOILER_GAS → AIR_CONDITIONER    115
# OTHER → STOVE                   105
# OTHER → AIR_CONDITIONER          94
# OTHER → BOILER_GAS               88
# AIR_CONDITIONER → STOVE          88
# HEAT_PUMP → AIR_CONDITIONER      83
# STOVE → HEAT_PUMP                81
# STOVE → OTHER                    73
# Name: count, dtype: int64
#
# Total switcher segments to plot: 16
# Saved: cohort_curves_agency_boiler.png — 15 agencies plotted
# Saved: cohort_curves_agency_stove.png — 12 agencies plotted
# Saved: cohort_curves_agency_ac.png — 14 agencies plotted
# Saved: cohort_curves_agency_hp.png — 15 agencies plotted
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# Full dataset:     25,716 customers
# Excluding 3 LBCs: 23,698 customers
# Removed:          2,018 customers
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# BOILER_GAS → BOILER_GAS              6546
# STOVE → STOVE                        5727
# AIR_CONDITIONER → AIR_CONDITIONER    4794
# HEAT_PUMP → HEAT_PUMP                3927
# OTHER → OTHER                        2429
# HEAT_PUMP → OTHER                     275
# OTHER → HEAT_PUMP                     224
# BOILER_GAS → HEAT_PUMP                215
# HEAT_PUMP → STOVE                     182
# BOILER_GAS → OTHER                    142
# AIR_CONDITIONER → HEAT_PUMP           136
# AIR_CONDITIONER → OTHER               124
# HEAT_PUMP → BOILER_GAS                120
# BOILER_GAS → AIR_CONDITIONER          115
# OTHER → STOVE                         105
# OTHER → AIR_CONDITIONER                94
# OTHER → BOILER_GAS                     88
# AIR_CONDITIONER → STOVE                88
# HEAT_PUMP → AIR_CONDITIONER            83
# STOVE → HEAT_PUMP                      81
# STOVE → OTHER                          73
# STOVE → AIR_CONDITIONER                45
# AIR_CONDITIONER → BOILER_GAS           44
# BOILER_GAS → STOVE                     43
# STOVE → BOILER_GAS                     16
# Name: count, dtype: int64
#
# Total customers: 25,716
# Multi-product journeys: 2,293
# segment
# HEAT_PUMP → OTHER               275
# OTHER → HEAT_PUMP               224
# BOILER_GAS → HEAT_PUMP          215
# HEAT_PUMP → STOVE               182
# BOILER_GAS → OTHER              142
# AIR_CONDITIONER → HEAT_PUMP     136
# AIR_CONDITIONER → OTHER         124
# HEAT_PUMP → BOILER_GAS          120
# BOILER_GAS → AIR_CONDITIONER    115
# OTHER → STOVE                   105
# OTHER → AIR_CONDITIONER          94
# OTHER → BOILER_GAS               88
# AIR_CONDITIONER → STOVE          88
# HEAT_PUMP → AIR_CONDITIONER      83
# STOVE → HEAT_PUMP                81
# STOVE → OTHER                    73
# Name: count, dtype: int64
#
# Total switcher segments to plot: 16
# Saved: cohort_curves_agency_boiler_process.png
# Saved: cohort_curves_agency_stove_process.png
# Saved: cohort_curves_agency_ac_process.png
# Saved: cohort_curves_agency_hp_process.png
