# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import chi2_contingency
from datetime import timedelta

from cohorts.process import plot_agency_process_cohorts

import warnings
warnings.filterwarnings('ignore')

df_clean = pd.read_csv('pipeline_data/cleaned_quote_data.csv')
df_clean['dt_creation_devis'] = pd.to_datetime(df_clean['dt_creation_devis'])
print(f"Loaded data: {len(df_clean):,} quotes from {df_clean['numero_compte'].nunique():,} customers")

print(df_clean.shape)
# print(df_clean.dtypes)
# print(df_clean.head(3).to_string())
# Out:
# Loaded data: 37,008 quotes from 25,716 customers
# (37008, 50)

# %%
plot_agency_process_cohorts(df_clean)
# Out:
# Saved: pipeline_data/cohort_curves_agency_boiler_process.png
# Saved: pipeline_data/cohort_curves_agency_stove_process.png
# Saved: pipeline_data/cohort_curves_agency_ac_process.png
# Saved: pipeline_data/cohort_curves_agency_heat_pump_process.png
